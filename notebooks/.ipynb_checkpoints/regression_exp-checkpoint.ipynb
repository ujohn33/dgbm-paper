# %%
import os
os.chdir(os.path.dirname(os.getcwd()))

# %%
from argparse import ArgumentParser
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split
from ucimlrepo import fetch_ucirepo 
from scipy.io import arff
from lightgbmlss.model import *
from lightgbmlss.distributions.Gaussian import *
from scipy.stats import norm

np.random.seed(1)

# %%
dataset_name_to_loader = {
    "Boston Housing": lambda: pd.read_csv(
        "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data",
        header=None,
        delim_whitespace=True,
    ),
    "Concrete Compression Strength": lambda: pd.read_excel(
        "https://archive.ics.uci.edu/ml/machine-learning-databases/concrete/compressive/Concrete_Data.xls"
    ),
    "Energy Efficiency": lambda: pd.read_excel(
        "https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx"
    ).iloc[:, :-1],
    "Kin8nm": lambda: pd.read_csv("ngboost/data/uci/kin8nm.csv"),
    "Naval Propulsion": lambda: pd.read_csv(
        "ngboost/data/uci/naval-propulsion.txt", delim_whitespace=True, header=None
    ).iloc[:, :-1],
    "Combined Cycle Power Plant": lambda: pd.read_excel("ngboost/data/uci/power-plant.xlsx"),
    "Protein Structure": lambda: pd.read_csv("ngboost/data/uci/protein.csv")[
        ["F1", "F2", "F3", "F4", "F5", "F6", "F7", "F8", "F9", "RMSD"]
    ],
    "Wine Quality Red": lambda: pd.read_csv(
        "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv",
        delimiter=";",
    ),
    "Yacht Hydrodynamics": lambda: pd.read_csv(
        "http://archive.ics.uci.edu/ml/machine-learning-databases/00243/yacht_hydrodynamics.data",
        header=None,
        delim_whitespace=True,
    ),
    "Year Prediciton MSD": lambda: pd.read_csv("ngboost/data/uci/YearPredictionMSD.txt").iloc[:, ::-1],
}

dataset_list = ["Boston Housing", "Concrete Compression Strength", "Energy Efficiency", "Kin8nm", "Naval Propulsion", "Combined Cycle Power Plant", "Protein Structure", "Wine Quality Red", "Yacht Hydrodynamics", "Year Prediciton MSD"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 34
#       1 dataset_name_to_loader = {
#       2     "Boston Housing": lambda: pd.read_csv(
#       3         "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data",
#    (...)
#      30     "Year Prediciton MSD": lambda: pd.read_csv("ngboost/data/uci/YearPredictionMSD.txt").iloc[:, ::-1],
#      31 }
#      33 base_name_to_learner = {
# ---> 34     "tree": default_tree_learner,
#      35     "linear": default_linear_learner,
#      36 }
#      38 dataset_list = ["Boston Housing", "Concrete Compression Strength", "Energy Efficiency", "Kin8nm", "Naval Propulsion", "Combined Cycle Power Plant", "Protein Structure", "Wine Quality Red", "Yacht Hydrodynamics", "Year Prediciton MSD"]
#
# NameError: name 'default_tree_learner' is not defined

# %%
# Hardcoded parameters for testing
args = {
    "dataset": "Concrete Compression Strength",
    "reps": 5,
    "n_est": 2000,
    "n_splits": 20,
    "score": "MLE",
    "distn": "Normal",
    "base": "tree",
    "verbose": True,
}

with open('LSSboost_performance_logloss.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Dataset', ' RMSE Mean', 'LSSboost RMSE Std', 'LSSboost NLL Mean', 'LSSboost NLL Std'])
    for dset in dataset_list:
        args["dataset"] = dset
        y_true, lss_rmse, lss_nll = [], [], []

        # Load dataset -- use last column as label
        data = dataset_name_to_loader[args['dataset']]()
        X, y = data.iloc[:, :-1].values, data.iloc[:, -1].values

        print(f"== Dataset={args['dataset']} X.shape={str(X.shape)} {args['score']}/{args['distn']}")

        lgbm_rmse = []
        if args["dataset"] == "Year Prediciton MSD":
            folds = [(np.arange(463715), np.arange(463715, len(X)))]
            default_params = {
                "eta":                     1e-1,
                "max_depth":                3,
                "subsample":                0.1,
            }
        elif args["dataset"] == "Protein Structure":
            default_params = {
                "eta":                     1e-2,
                "max_depth":                5,
                "subsample":                1,
            }
            kf = KFold(n_splits=5)
            folds = kf.split(X)
            # Follow https://github.com/yaringal/DropoutUncertaintyExps/blob/master/UCI_Datasets/concrete/data/split_data_train_test.py
            n = X.shape[0]
            np.random.seed(1)
            folds = []
            for i in range(5):
                permutation = np.random.choice(range(n), n, replace=False)
                end_train = round(n * 9.0 / 10)
                end_test = n

                train_index = permutation[0:end_train]
                test_index = permutation[end_train:n]
                folds.append((train_index, test_index))        
        else:
            default_params = {
                "eta":                     1e-2,
                "max_depth":                5,
                "subsample":                1,
            }
            kf = KFold(n_splits=args["n_splits"])
            folds = kf.split(X)
            # Follow https://github.com/yaringal/DropoutUncertaintyExps/blob/master/UCI_Datasets/concrete/data/split_data_train_test.py
            n = X.shape[0]
            np.random.seed(1)
            folds = []
            for i in range(args['n_splits']):
                permutation = np.random.choice(range(n), n, replace=False)
                end_train = round(n * 9.0 / 10)
                end_test = n

                train_index = permutation[0:end_train]
                test_index = permutation[end_train:n]
                folds.append((train_index, test_index))


        for itr, (train_index, test_index) in enumerate(folds):
            # print('train_index: ')
            # print(train_index)
            # print('test_index: ')
            # print(test_index)
            X_trainall, X_test = X[train_index], X[test_index]
            y_trainall, y_test = y[train_index], y[test_index]

            X_train, X_val, y_train, y_val = train_test_split(
                X_trainall, y_trainall, test_size=0.2
            )

            y_true += list(y_test.flatten())


            lgblss = LightGBMLSS(
                Gaussian(stabilization="None",
                        response_fn = "exp",
                        loss_fn = "nll")
            )

            dtrain = lgb.Dataset(X_train, y_train)
            deval = lgb.Dataset(X_val, y_val)
            dtest = lgb.Dataset(X_test, y_test)
            # Training with early stopping
            evals_result = {}
            default_params['early_stopping'] = 20
            # Train Model with optimized hyperparameters
            gbm = lgblss.train(default_params, dtrain, 
                               num_boost_round = args["n_est"],
                               valid_sets = [dtrain, deval]
                              )

            # Best iteration
            print(f"Best iteration: {lgblss.booster.best_iteration}")

            full_train_data = lgb.Dataset(X_trainall, y_trainall)
            default_params['early_stopping'] = None

            final_gbm = lgblss.train(default_params, full_train_data, 
                               num_boost_round = lgblss.booster.best_iteration,
                         )
            # the final prediction for this fold
            forecast = lgblss.predict(X_test)
            forecast_val = lgblss.predict(X_val)

            lss_rmse += [np.sqrt(mean_squared_error(forecast['loc'].values, y_test))]
            val_rmse = [np.sqrt(mean_squared_error(forecast_val['loc'].values, y_val))]
            lss_nll += [-norm(forecast['loc'], forecast['scale']).logpdf(y_test.flatten()).mean()]

            print(
                    "[%d/%d] BestIter=%d RMSE: Val=%.4f Test=%.4f NLL: Test=%.4f"
                    % (
                        itr + 1,
                        args['n_splits'],
                        lgblss.booster.best_iteration,
                        np.sqrt(val_rmse),
                        np.sqrt(mean_squared_error(forecast['loc'].values, y_test)),
                        lss_nll[-1],
                    )
                )
        print(dset)
        print(
                "== GBM=%.4f +/- %.4f, RMSE GBMLSS=%.4f ± %.4f, NLL GBMLSS=%.4f ± %.4f"
                % (
                    0.0,
                    0.0,
                    np.mean(lss_rmse),
                    np.std(lss_rmse),
                    np.mean(lss_nll),
                    np.std(lss_nll),
                )
            )
        writer.writerow([
            dset,
            np.mean(lss_rmse),  # LSSboost RMSE Mean
            np.std(lss_rmse),   # LSSboost RMSE Std
            np.mean(lss_nll),   # LSSboost NLL Mean
            np.std(lss_nll)     # LSSboost NLL Std
        ])
# Out:
# == Dataset=Boston Housing X.shape=(506, 13) MLE/Normal
# Best iteration: 236
# [1/20] BestIter=0 RMSE: Val=1.9938 Test=2.7234 NLL: Test=2.4123
# Best iteration: 116
# [2/20] BestIter=0 RMSE: Val=2.2341 Test=4.3637 NLL: Test=2.7813
# Best iteration: 184
# [3/20] BestIter=0 RMSE: Val=1.8315 Test=3.5606 NLL: Test=2.5609
# Best iteration: 144
# [4/20] BestIter=0 RMSE: Val=1.9962 Test=4.5289 NLL: Test=2.6072
# Best iteration: 71
# [5/20] BestIter=0 RMSE: Val=2.6081 Test=7.7940 NLL: Test=3.0549
# Best iteration: 181
# [6/20] BestIter=0 RMSE: Val=2.3158 Test=3.4289 NLL: Test=2.6557
# Best iteration: 258
# [7/20] BestIter=0 RMSE: Val=2.2502 Test=1.8465 NLL: Test=2.2386
# Best iteration: 159
# [8/20] BestIter=0 RMSE: Val=1.9811 Test=5.3425 NLL: Test=2.5654
# Best iteration: 88
# [9/20] BestIter=0 RMSE: Val=2.4481 Test=5.0630 NLL: Test=2.9423
# Best iteration: 174
# [10/20] BestIter=0 RMSE: Val=1.8729 Test=5.4737 NLL: Test=2.6540
# Best iteration: 145
# [11/20] BestIter=0 RMSE: Val=2.1509 Test=4.8401 NLL: Test=2.7456
# Best iteration: 193
# [12/20] BestIter=0 RMSE: Val=1.9315 Test=4.7693 NLL: Test=2.7004
# Best iteration: 121
# [13/20] BestIter=0 RMSE: Val=2.3086 Test=4.0585 NLL: Test=2.5614
# Best iteration: 208
# [14/20] BestIter=0 RMSE: Val=1.7060 Test=5.1743 NLL: Test=2.9296
# Best iteration: 156
# [15/20] BestIter=0 RMSE: Val=1.9311 Test=4.0125 NLL: Test=2.6387
# Best iteration: 206
# [16/20] BestIter=0 RMSE: Val=1.5995 Test=3.5023 NLL: Test=2.4673
# Best iteration: 133
# [17/20] BestIter=0 RMSE: Val=2.1476 Test=3.9634 NLL: Test=2.6750
# Best iteration: 170
# [18/20] BestIter=0 RMSE: Val=2.0296 Test=3.8432 NLL: Test=2.6847
# Best iteration: 164
# [19/20] BestIter=0 RMSE: Val=2.1746 Test=3.7856 NLL: Test=2.5116
# Best iteration: 188
# [20/20] BestIter=0 RMSE: Val=2.0474 Test=6.7886 NLL: Test=2.7145
# Boston Housing
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=4.4432 ± 1.2951, NLL GBMLSS=2.6551 ± 0.1824
# == Dataset=Concrete Compression Strength X.shape=(1030, 8) MLE/Normal
# Best iteration: 248
# [1/20] BestIter=0 RMSE: Val=2.5602 Test=7.2751 NLL: Test=3.1995
# Best iteration: 312
# [2/20] BestIter=0 RMSE: Val=2.5512 Test=5.7716 NLL: Test=3.2049
# Best iteration: 290
# [3/20] BestIter=0 RMSE: Val=2.4648 Test=6.4706 NLL: Test=3.0574
# Best iteration: 424
# [4/20] BestIter=0 RMSE: Val=2.2131 Test=6.2009 NLL: Test=3.8829
# Best iteration: 383
# [5/20] BestIter=0 RMSE: Val=2.3748 Test=5.6548 NLL: Test=3.1368
# Best iteration: 315
# [6/20] BestIter=0 RMSE: Val=2.2893 Test=5.8691 NLL: Test=2.9977
# Best iteration: 270
# [7/20] BestIter=0 RMSE: Val=2.3725 Test=6.7937 NLL: Test=3.2032
# Best iteration: 292
# [8/20] BestIter=0 RMSE: Val=2.5227 Test=6.1344 NLL: Test=3.1713
# Best iteration: 295
# [9/20] BestIter=0 RMSE: Val=2.3358 Test=6.0182 NLL: Test=3.0454
# Best iteration: 262
# [10/20] BestIter=0 RMSE: Val=2.4815 Test=7.4503 NLL: Test=3.4963
# Best iteration: 232
# [11/20] BestIter=0 RMSE: Val=2.5824 Test=5.7029 NLL: Test=2.9846
# Best iteration: 290
# [12/20] BestIter=0 RMSE: Val=2.4234 Test=6.6013 NLL: Test=3.2229
# Best iteration: 327
# [13/20] BestIter=0 RMSE: Val=2.1973 Test=6.8240 NLL: Test=3.1469
# Best iteration: 243
# [14/20] BestIter=0 RMSE: Val=2.4440 Test=6.0219 NLL: Test=3.0726
# Best iteration: 275
# [15/20] BestIter=0 RMSE: Val=2.2910 Test=6.7203 NLL: Test=3.1429
# Best iteration: 243
# [16/20] BestIter=0 RMSE: Val=2.3215 Test=5.7554 NLL: Test=3.2086
# Best iteration: 317
# [17/20] BestIter=0 RMSE: Val=2.1585 Test=6.6662 NLL: Test=3.3763
# Best iteration: 243
# [18/20] BestIter=0 RMSE: Val=2.3787 Test=6.2804 NLL: Test=3.0236
# Best iteration: 258
# [19/20] BestIter=0 RMSE: Val=2.3943 Test=7.7335 NLL: Test=3.3152
# Best iteration: 257
# [20/20] BestIter=0 RMSE: Val=2.4704 Test=6.0423 NLL: Test=3.1478
# Concrete Compression Strength
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=6.3993 ± 0.5863, NLL GBMLSS=3.2018 ± 0.1990
# == Dataset=Energy Efficiency X.shape=(768, 8) MLE/Normal
# Best iteration: 432
# [1/20] BestIter=0 RMSE: Val=1.4047 Test=2.0634 NLL: Test=0.9848
# Best iteration: 758
# [2/20] BestIter=0 RMSE: Val=1.3000 Test=2.5841 NLL: Test=5.7174
# Best iteration: 442
# [3/20] BestIter=0 RMSE: Val=1.3674 Test=2.2746 NLL: Test=0.8757
# Best iteration: 590
# [4/20] BestIter=0 RMSE: Val=1.3587 Test=1.3957 NLL: Test=0.7560
# Best iteration: 848
# [5/20] BestIter=0 RMSE: Val=1.1228 Test=1.4261 NLL: Test=1.3300
# Best iteration: 408
# [6/20] BestIter=0 RMSE: Val=1.3709 Test=2.0005 NLL: Test=0.9911
# Best iteration: 572
# [7/20] BestIter=0 RMSE: Val=1.2488 Test=2.0333 NLL: Test=0.8286
# Best iteration: 524
# [8/20] BestIter=0 RMSE: Val=1.2320 Test=2.0543 NLL: Test=0.8925
# Best iteration: 701
# [9/20] BestIter=0 RMSE: Val=1.3245 Test=1.9577 NLL: Test=6.5471
# Best iteration: 1320
# [10/20] BestIter=0 RMSE: Val=1.4005 Test=2.6410 NLL: Test=1.2140
# Best iteration: 411
# [11/20] BestIter=0 RMSE: Val=1.2124 Test=1.3518 NLL: Test=0.9265
# Best iteration: 423
# [12/20] BestIter=0 RMSE: Val=1.4750 Test=2.0024 NLL: Test=0.9433
# Best iteration: 845
# [13/20] BestIter=0 RMSE: Val=1.2402 Test=1.3284 NLL: Test=4.0900
# Best iteration: 409
# [14/20] BestIter=0 RMSE: Val=1.3329 Test=2.0828 NLL: Test=1.1636
# Best iteration: 733
# [15/20] BestIter=0 RMSE: Val=1.1902 Test=1.1377 NLL: Test=0.6149
# Best iteration: 720
# [16/20] BestIter=0 RMSE: Val=1.0400 Test=1.5529 NLL: Test=0.5161
# Best iteration: 717
# [17/20] BestIter=0 RMSE: Val=1.2637 Test=0.9825 NLL: Test=2.1493
# Best iteration: 652
# [18/20] BestIter=0 RMSE: Val=1.4011 Test=2.1631 NLL: Test=0.8947
# Best iteration: 417
# [19/20] BestIter=0 RMSE: Val=1.0847 Test=1.9122 NLL: Test=1.2138
# Best iteration: 1207
# [20/20] BestIter=0 RMSE: Val=1.1896 Test=1.6834 NLL: Test=0.7744
# Energy Efficiency
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=1.8314 ± 0.4447, NLL GBMLSS=1.6712 ± 1.6685
# == Dataset=Kin8nm X.shape=(8192, 8) MLE/Normal
# Best iteration: 602
# [1/20] BestIter=0 RMSE: Val=0.3755 Test=0.1593 NLL: Test=-0.4692
# Best iteration: 568
# [2/20] BestIter=0 RMSE: Val=0.3801 Test=0.1581 NLL: Test=-0.4942
# Best iteration: 471
# [3/20] BestIter=0 RMSE: Val=0.3898 Test=0.1610 NLL: Test=-0.4768
# Best iteration: 628
# [4/20] BestIter=0 RMSE: Val=0.3713 Test=0.1568 NLL: Test=-0.5262
# Best iteration: 585
# [5/20] BestIter=0 RMSE: Val=0.3709 Test=0.1621 NLL: Test=-0.5000
# Best iteration: 629
# [6/20] BestIter=0 RMSE: Val=0.3629 Test=0.1553 NLL: Test=-0.5310
# Best iteration: 573
# [7/20] BestIter=0 RMSE: Val=0.3748 Test=0.1570 NLL: Test=-0.5403
# Best iteration: 589
# [8/20] BestIter=0 RMSE: Val=0.3783 Test=0.1549 NLL: Test=-0.5510
# Best iteration: 596
# [9/20] BestIter=0 RMSE: Val=0.3780 Test=0.1484 NLL: Test=-0.5958
# Best iteration: 612
# [10/20] BestIter=0 RMSE: Val=0.3751 Test=0.1591 NLL: Test=-0.4871
# Best iteration: 580
# [11/20] BestIter=0 RMSE: Val=0.3710 Test=0.1559 NLL: Test=-0.5025
# Best iteration: 582
# [12/20] BestIter=0 RMSE: Val=0.3761 Test=0.1654 NLL: Test=-0.4643
# Best iteration: 554
# [13/20] BestIter=0 RMSE: Val=0.3809 Test=0.1590 NLL: Test=-0.4908
# Best iteration: 556
# [14/20] BestIter=0 RMSE: Val=0.3771 Test=0.1594 NLL: Test=-0.5026
# Best iteration: 542
# [15/20] BestIter=0 RMSE: Val=0.3781 Test=0.1557 NLL: Test=-0.5300
# Best iteration: 704
# [16/20] BestIter=0 RMSE: Val=0.3718 Test=0.1572 NLL: Test=-0.5416
# Best iteration: 643
# [17/20] BestIter=0 RMSE: Val=0.3736 Test=0.1577 NLL: Test=-0.4603
# Best iteration: 599
# [18/20] BestIter=0 RMSE: Val=0.3733 Test=0.1584 NLL: Test=-0.4767
# Best iteration: 599
# [19/20] BestIter=0 RMSE: Val=0.3711 Test=0.1644 NLL: Test=-0.5048
# Best iteration: 457
# [20/20] BestIter=0 RMSE: Val=0.3853 Test=0.1690 NLL: Test=-0.4382
# Kin8nm
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=0.1587 ± 0.0043, NLL GBMLSS=-0.5042 ± 0.0363
# == Dataset=Naval Propulsion X.shape=(11934, 16) MLE/Normal
# Best iteration: 1997
# [1/20] BestIter=0 RMSE: Val=0.0439 Test=0.0024 NLL: Test=-5.3837
# Best iteration: 2000
# [2/20] BestIter=0 RMSE: Val=0.0481 Test=0.0022 NLL: Test=-5.3292
# Best iteration: 2000
# [3/20] BestIter=0 RMSE: Val=0.0505 Test=0.0024 NLL: Test=-5.4326
# Best iteration: 2000
# [4/20] BestIter=0 RMSE: Val=0.0479 Test=0.0028 NLL: Test=-5.4285
# Best iteration: 2000
# [5/20] BestIter=0 RMSE: Val=0.0499 Test=0.0029 NLL: Test=-5.3941
# [10/20] BestIter=0 RMSE: Val=0.0441 Test=0.0021 NLL: Test=-5.4012
# Best iteration: 2000
# [11/20] BestIter=0 RMSE: Val=0.0449 Test=0.0025 NLL: Test=-5.4432
# Best iteration: 1960
# [12/20] BestIter=0 RMSE: Val=0.0483 Test=0.0024 NLL: Test=-5.4095
# Best iteration: 1999
# [13/20] BestIter=0 RMSE: Val=0.0468 Test=0.0031 NLL: Test=-5.3962
# Best iteration: 2000
# [14/20] BestIter=0 RMSE: Val=0.0467 Test=0.0022 NLL: Test=-5.4535
# Best iteration: 2000
# [15/20] BestIter=0 RMSE: Val=0.0463 Test=0.0022 NLL: Test=-5.5152
# Best iteration: 1999
# [16/20] BestIter=0 RMSE: Val=0.0477 Test=0.0025 NLL: Test=-5.4396
# Best iteration: 2000
# [17/20] BestIter=0 RMSE: Val=0.0488 Test=0.0023 NLL: Test=-5.4640
# Best iteration: 2000
# [18/20] BestIter=0 RMSE: Val=0.0468 Test=0.0024 NLL: Test=-5.4532
# Best iteration: 2000
# [19/20] BestIter=0 RMSE: Val=0.0512 Test=0.0022 NLL: Test=-5.4747
# Best iteration: 2000
# [20/20] BestIter=0 RMSE: Val=0.0450 Test=0.0023 NLL: Test=-5.3969
# Naval Propulsion
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=0.0025 ± 0.0005, NLL GBMLSS=-5.3885 ± 0.1410
# == Dataset=Combined Cycle Power Plant X.shape=(9568, 4) MLE/Normal
# Best iteration: 288
# [1/20] BestIter=0 RMSE: Val=2.0134 Test=4.1762 NLL: Test=2.8084
# Best iteration: 466
# [2/20] BestIter=0 RMSE: Val=1.9203 Test=3.9364 NLL: Test=2.7753
# Best iteration: 535
# [3/20] BestIter=0 RMSE: Val=1.8525 Test=3.7190 NLL: Test=2.6855
# Best iteration: 237
# [4/20] BestIter=0 RMSE: Val=2.1107 Test=4.1453 NLL: Test=2.8407
# Best iteration: 398
# [5/20] BestIter=0 RMSE: Val=1.9867 Test=4.2996 NLL: Test=2.8160
# Best iteration: 301
# [6/20] BestIter=0 RMSE: Val=2.0143 Test=4.3995 NLL: Test=2.9210
# Best iteration: 243
# [7/20] BestIter=0 RMSE: Val=2.0603 Test=4.2322 NLL: Test=2.8525
# Best iteration: 587
# [8/20] BestIter=0 RMSE: Val=1.8637 Test=3.7952 NLL: Test=2.7255
# Best iteration: 623
# [9/20] BestIter=0 RMSE: Val=1.9066 Test=3.8937 NLL: Test=2.7997
# Best iteration: 258
# [10/20] BestIter=0 RMSE: Val=2.0405 Test=4.3384 NLL: Test=2.8262
# Best iteration: 260
# [11/20] BestIter=0 RMSE: Val=2.1116 Test=4.1023 NLL: Test=2.7987
# Best iteration: 540
# [12/20] BestIter=0 RMSE: Val=1.8867 Test=3.9865 NLL: Test=2.8242
# Best iteration: 451
# [13/20] BestIter=0 RMSE: Val=1.9147 Test=3.8020 NLL: Test=2.6960
# Best iteration: 446
# [14/20] BestIter=0 RMSE: Val=1.8724 Test=3.6324 NLL: Test=2.6671
# Best iteration: 1008
# [15/20] BestIter=0 RMSE: Val=1.8478 Test=3.6631 NLL: Test=2.6524
# Best iteration: 782
# [16/20] BestIter=0 RMSE: Val=1.8514 Test=3.4778 NLL: Test=2.6004
# Best iteration: 436
# [17/20] BestIter=0 RMSE: Val=1.9060 Test=3.8768 NLL: Test=2.7264
# Best iteration: 724
# [18/20] BestIter=0 RMSE: Val=1.8401 Test=4.0037 NLL: Test=3.7737
# Best iteration: 446
# [19/20] BestIter=0 RMSE: Val=1.9234 Test=4.0650 NLL: Test=3.4934
# Best iteration: 458
# [20/20] BestIter=0 RMSE: Val=1.9190 Test=3.7067 NLL: Test=2.7324
# Combined Cycle Power Plant
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=3.9626 ± 0.2505, NLL GBMLSS=2.8508 ± 0.2754
# == Dataset=Protein Structure X.shape=(45730, 9) MLE/Normal
# Best iteration: 1210
# [1/20] BestIter=0 RMSE: Val=2.0379 Test=4.4959 NLL: Test=2.8840
# Best iteration: 1353
# [2/20] BestIter=0 RMSE: Val=2.0409 Test=4.4184 NLL: Test=3.2235
# Best iteration: 498
# [3/20] BestIter=0 RMSE: Val=2.0956 Test=4.5877 NLL: Test=2.8556
# Best iteration: 631
# [4/20] BestIter=0 RMSE: Val=2.0952 Test=4.5550 NLL: Test=2.7878
# Best iteration: 610
# [5/20] BestIter=0 RMSE: Val=2.0969 Test=4.5425 NLL: Test=2.8998
# Protein Structure
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=4.5199 ± 0.0587, NLL GBMLSS=2.9301 ± 0.1516
# == Dataset=Wine Quality Red X.shape=(1599, 11) MLE/Normal
# Best iteration: 141
# [1/20] BestIter=0 RMSE: Val=0.7793 Test=0.6420 NLL: Test=0.9046
# Best iteration: 105
# [2/20] BestIter=0 RMSE: Val=0.8020 Test=0.6282 NLL: Test=0.9290
# Best iteration: 162
# [3/20] BestIter=0 RMSE: Val=0.7553 Test=0.7589 NLL: Test=1.1317
# Best iteration: 145
# [4/20] BestIter=0 RMSE: Val=0.7511 Test=0.6000 NLL: Test=0.8695
# Best iteration: 157
# [5/20] BestIter=0 RMSE: Val=0.7467 Test=0.5855 NLL: Test=0.8256
# Best iteration: 173
# [6/20] BestIter=0 RMSE: Val=0.7427 Test=0.6258 NLL: Test=0.9549
# Best iteration: 183
# [7/20] BestIter=0 RMSE: Val=0.7413 Test=0.6761 NLL: Test=0.9798
# Best iteration: 178
# [8/20] BestIter=0 RMSE: Val=0.7345 Test=0.6751 NLL: Test=1.0032
# Best iteration: 201
# [9/20] BestIter=0 RMSE: Val=0.7073 Test=0.6056 NLL: Test=0.9920
# Best iteration: 197
# [10/20] BestIter=0 RMSE: Val=0.7329 Test=0.6693 NLL: Test=1.0079
# Best iteration: 128
# [11/20] BestIter=0 RMSE: Val=0.7847 Test=0.6615 NLL: Test=0.9559
# Best iteration: 81
# [12/20] BestIter=0 RMSE: Val=0.8696 Test=0.6622 NLL: Test=0.9878
# Best iteration: 186
# [13/20] BestIter=0 RMSE: Val=0.7355 Test=0.6464 NLL: Test=0.9431
# Best iteration: 160
# [14/20] BestIter=0 RMSE: Val=0.7686 Test=0.6069 NLL: Test=0.9235
# Best iteration: 133
# [15/20] BestIter=0 RMSE: Val=0.8003 Test=0.6326 NLL: Test=0.9209
# Best iteration: 192
# [16/20] BestIter=0 RMSE: Val=0.7509 Test=0.5526 NLL: Test=0.8133
# Best iteration: 159
# [17/20] BestIter=0 RMSE: Val=0.7423 Test=0.6201 NLL: Test=0.8833
# Best iteration: 149
# [18/20] BestIter=0 RMSE: Val=0.7462 Test=0.6311 NLL: Test=0.8773
# Best iteration: 173
# [19/20] BestIter=0 RMSE: Val=0.7487 Test=0.6304 NLL: Test=0.9040
# Best iteration: 206
# [20/20] BestIter=0 RMSE: Val=0.7178 Test=0.6332 NLL: Test=0.9394
# Wine Quality Red
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=0.6372 ± 0.0412, NLL GBMLSS=0.9373 ± 0.0696
# == Dataset=Yacht Hydrodynamics X.shape=(308, 6) MLE/Normal
# Best iteration: 625
# [1/20] BestIter=0 RMSE: Val=2.7068 Test=8.4940 NLL: Test=0.4965
# Best iteration: 554
# [2/20] BestIter=0 RMSE: Val=3.0958 Test=8.5183 NLL: Test=0.5842
# Best iteration: 634
# [3/20] BestIter=0 RMSE: Val=3.3985 Test=5.7752 NLL: Test=1.0189
# Best iteration: 606
# [4/20] BestIter=0 RMSE: Val=3.3586 Test=12.3383 NLL: Test=0.9961
# Best iteration: 571
# [5/20] BestIter=0 RMSE: Val=3.0209 Test=11.3070 NLL: Test=1.1462
# Best iteration: 530
# [6/20] BestIter=0 RMSE: Val=3.2781 Test=5.9588 NLL: Test=0.5271
# Best iteration: 788
# [7/20] BestIter=0 RMSE: Val=2.5811 Test=1.4417 NLL: Test=1.2915
# Best iteration: 443
# [8/20] BestIter=0 RMSE: Val=3.2286 Test=9.1739 NLL: Test=0.6937
# Best iteration: 582
# [9/20] BestIter=0 RMSE: Val=3.0864 Test=7.1033 NLL: Test=0.3231
# Best iteration: 700
# [10/20] BestIter=0 RMSE: Val=2.7215 Test=4.0655 NLL: Test=-0.2671
# Best iteration: 568
# [11/20] BestIter=0 RMSE: Val=2.7581 Test=12.1846 NLL: Test=1.7002
# Best iteration: 703
# [12/20] BestIter=0 RMSE: Val=3.1801 Test=7.2944 NLL: Test=0.6874
# Best iteration: 616
# [13/20] BestIter=0 RMSE: Val=3.2803 Test=11.3570 NLL: Test=0.8503
# Best iteration: 283
# [14/20] BestIter=0 RMSE: Val=3.0203 Test=11.0824 NLL: Test=1.7729
# Best iteration: 633
# [15/20] BestIter=0 RMSE: Val=2.8743 Test=10.4610 NLL: Test=0.6587
# Best iteration: 626
# [16/20] BestIter=0 RMSE: Val=2.9216 Test=8.1268 NLL: Test=0.3662
# Best iteration: 556
# [17/20] BestIter=0 RMSE: Val=2.5580 Test=7.2569 NLL: Test=0.6691
# Best iteration: 586
# [18/20] BestIter=0 RMSE: Val=3.2381 Test=8.4457 NLL: Test=0.7672
# Best iteration: 624
# [19/20] BestIter=0 RMSE: Val=3.0500 Test=9.9654 NLL: Test=0.5489
# Best iteration: 557
# [20/20] BestIter=0 RMSE: Val=2.8302 Test=12.8055 NLL: Test=1.2756
# Yacht Hydrodynamics
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=8.6578 ± 2.8633, NLL GBMLSS=0.8053 ± 0.4651
# == Dataset=Year Prediciton MSD X.shape=(515344, 90) MLE/Normal
# Best iteration: 1334
# [1/20] BestIter=0 RMSE: Val=3.0071 Test=9.1068 NLL: Test=3.4188
# Year Prediciton MSD
# == GBM=0.0000 +/- 0.0000, RMSE GBMLSS=9.1068 ± 0.0000, NLL GBMLSS=3.4188 ± 0.0000

# %%
# the final prediction for this fold
forecast = lgblss.predict(X_test)
forecast_val = lgblss.predict(X_val)

lss_rmse += [np.sqrt(mean_squared_error(forecast['loc'].values, y_test))]
val_rmse = [np.sqrt(mean_squared_error(forecast_val['loc'].values, y_val))]
lss_nll += [-norm(forecast['loc'], forecast['scale']).logpdf(y_test.flatten()).mean()]

print(
        "[%d/%d] BestIter=%d RMSE: Val=%.4f Test=%.4f NLL: Test=%.4f"
        % (
            itr + 1,
            args['n_splits'],
            lgblss.booster.best_iteration,
            np.sqrt(val_rmse),
            np.sqrt(mean_squared_error(forecast['loc'].values, y_test)),
            lss_nll[-1],
        )
    )
# Out:
# [1/20] BestIter=0 RMSE: Val=2.5229 Test=7.0629 NLL: Test=3.1941
