# %%
import os
os.environ['OPENML_CONFIG_DIR'] = '/data/brussel/105/vsc10528/.config'

# %%
import openml
openml.config.apikey = '0fc137c28db32cdfecb6347178c7be68'  # set the OpenML Api Key
SUITE_ID = 335

# %%
benchmark_suite.tasks
# Out:
# [361093,
#  361094,
#  361096,
#  361097,
#  361098,
#  361099,
#  361101,
#  361102,
#  361103,
#  361104,
#  361287,
#  361288,
#  361289,
#  361291,
#  361292,
#  361293,
#  361294]

# %%
# import openml
# openml.config.apikey = '0fc137c28db32cdfecb6347178c7be68'  # set the OpenML Api Key
# #SUITE_ID = 336 # Regression on numerical features
# SUITE_ID = 335 # Regression on numerical and categorical features
benchmark_suite = openml.study.get_suite(SUITE_ID)  # obtain the benchmark suite
for task_id in benchmark_suite.tasks:  # iterate over all tasks
    task = openml.tasks.get_task(task_id)  # download the OpenML task
    n_repeats, n_folds, n_samples = task.get_split_dimensions()
    print(
    "Task {}: number of repeats: {}, number of folds: {}, number of samples {}.".format(
        task_id,
        n_repeats,
        n_folds,
        n_samples,
        )
    )
    train_indices, test_indices = task.get_train_test_split_indices(
        repeat=0,
        fold=1,
        sample=0,
    )
    print(train_indices)
    print(test_indices)
    X_train = X.iloc[train_indices]
    X_test = X.iloc[test_indices]
    print(X_test)
    # dataset = task.get_dataset()
    # X, y, categorical_indicator, attribute_names = dataset.get_data(
    #     dataset_format="dataframe", target=dataset.default_target_attribute
    # )
# Out:
# Task 361093: number of repeats: 1, number of folds: 10, number of samples 1.
# [3015  938  206 ... 2929 3392  612]
# [1920 2485 1773 3658 3278 2479 3803  611 3872  416 1222 3361  517 3889
#   734 3657 3695 1859 3141 1925 1290 1616 3439  797 1734  243 3715  278
#   430  926 3244 3928 2084  709 3194 1573 1286  684  804 1622 2949 2487
#  4037 2954  511 3226 1264 3750 2256 3312 2162 2931  515  417  259 2912
#  2062  157 1188  843  853 2392 1282 1101 3861  456  898 2713 1560 2521
#  2867 3204 2641 2578  990 3329 1171 2935  747 3882  662 3343 3519  864
#  3826 3611 3711 2473 2285 2417 3236 3417  904 1882 3660 3220 2664 1969
#   651 2839  267 2431 2742    8  984 1552 3363  434 2666  956 1375 1182
#   236 3564  876 2654  383  354 3326  336 2382 3003 3385 1256  771 3628
#  3219 3600 1714 1794 3284 2947 3317   23 3756 1698 2793 3402 2026 1030
#   901 1776 3133 1170 1843 2525 1835 1725  623 3058 3293 2799 3730 1768
#  1281 1710 1729 2299 2775 3717 3975 2421  214 3273 3644 1411 3935 1623
# ...

# %%
X
# Out:
#        carat  depth  table     x     y     z
# 0       0.23   61.5   55.0  3.95  3.98  2.43
# 1       0.21   59.8   61.0  3.89  3.84  2.31
# 2       0.23   56.9   65.0  4.05  4.07  2.31
# 3       0.29   62.4   58.0  4.20  4.23  2.63
# 4       0.31   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0  5.75  5.76  3.50
# 53936   0.72   63.1   55.0  5.69  5.75  3.61
# 53937   0.70   62.8   60.0  5.66  5.68  3.56
# 53938   0.86   61.0   58.0  6.15  6.12  3.74
# 53939   0.75   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 6 columns]
